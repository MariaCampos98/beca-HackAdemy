# %% [markdown]
# ## HACKADEMY
# Ejercicio 1:
#
# * Imprimir mil veces un string sin usar un ciclo o una iteración

# %%
cadena = 'hola.'+ '\n'
print (cadena * 1000)
# Out:
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# hola.
# ...

# %%
cadena = input(' ') + '..'

print (cadena.upper() + " fue tu palabra ingresada \n"+ cadena * 1000)
# Out:
#  hi
# HI.. fue tu palabra ingresada
# ...

# %% [markdown]
# Ejercicio 2:
#
# * Si tienes 2 arreglos (1 con nombres de equipos y otro con cantidad de torneos) debes de acomodarlos del equipo más ganador al menos ganador. Datos de prueba.. (array equipo = ["PSG", "Chicago Bulls", "Tomateros", "Isotopos", "Rangers", "Isotopos"] array campeonatos = ["3", "5", "6", "4", "2", "9"])

# %%
array_equipo = ['PSG', 'Chicago Bulls', 'Tomateros', 'Isotopos', 'Rangers', 'Isotopos']
array_campeonatos = [3, 5, 6, 4, 2, 9]

join = dict(zip(array_campeonatos,array_equipo))

join
join_sorted= sorted(join.items())
print (join_sorted)
# Out:
# [(2, 'Rangers'), (3, 'PSG'), (4, 'Isotopos'), (5, 'Chicago Bulls'), (6, 'Tomateros'), (9, 'Isotopos')]
