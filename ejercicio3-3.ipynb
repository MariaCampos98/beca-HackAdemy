# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# !head data.json
# Out:
# {
# 	"data": [{
# 			"birthYear": 1923,
# 			"deathYear": 1926
# 		}, {
# 			"birthYear": 1920,
# 			"deathYear": 1961
# 		}, {
# 			"birthYear": 1941,
# 			"deathYear": 1971

# %%
import json
with open('data.json') as file:
    datos = json.loads(file.read())

    for birthYear in datos['data']:
        print('birthYear:', birthYear['birthYear'])
        
        print('')


with open('data.json') as json_file:
    datos1 = pd.read_json(json_file, orient='index')

    print()
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
#
# birthYear: 1918
#
# birthYear: 1948
#
# birthYear: 1918
#
# birthYear: 1924
#
# birthYear: 1916
#
# birthYear: 1942
#
# birthYear: 1929
#
# birthYear: 1918
#
# birthYear: 1938
#
# birthYear: 1904
#
# birthYear: 1915
#
# birthYear: 1939
#
# birthYear: 1947
#
# birthYear: 1927
#
# birthYear: 1909
#
# birthYear: 1945
#
# birthYear: 1935
#
# birthYear: 1908
#
# birthYear: 1945
#
# birthYear: 1905
#
# birthYear: 1938
#
# birthYear: 1945
#
# birthYear: 1915
#
# birthYear: 1937
#
# birthYear: 1901
#
# birthYear: 1902
#
# birthYear: 1909
#
# birthYear: 1905
#
# birthYear: 1941
#
# birthYear: 1929
#
# birthYear: 1936
#
# birthYear: 1919
#
# birthYear: 1911
#
# birthYear: 1925
#
# birthYear: 1902
#
# birthYear: 1909
#
# birthYear: 1931
#
# birthYear: 1919
#
# birthYear: 1911
#
# birthYear: 1915
#
# birthYear: 1925
#
# birthYear: 1909
#
# birthYear: 1936
#
# birthYear: 1914
#
# birthYear: 1926
#
# birthYear: 1927
#
# ...

# %%
import json
f = open("data.json","r")
c= f.read()
c
# Out:
# '{\n\t"data": [{\n\t\t\t"birthYear": 1923,\n\t\t\t"deathYear": 1926\n\t\t}, {\n\t\t\t"birthYear": 1920,\n\t\t\t"deathYear": 1961\n\t\t}, {\n\t\t\t"birthYear": 1941,\n\t\t\t"deathYear": 1971\n\t\t}, {\n\t\t\t"birthYear": 1902,\n\t\t\t"deathYear": 1936\n\t\t}, {\n\t\t\t"birthYear": 1948,\n\t\t\t"deathYear": 1949\n\t\t}, {\n\t\t\t"birthYear": 1924,\n\t\t\t"deathYear": 1946\n\t\t}, {\n\t\t\t"birthYear": 1914,\n\t\t\t"deathYear": 1958\n\t\t}, {\n\t\t\t"birthYear": 1930,\n\t\t\t"deathYear": 1965\n\t\t}, {\n\t\t\t"birthYear": 1939,\n\t\t\t"deathYear": 1971\n\t\t}, {\n\t\t\t"birthYear": 1940,\n\t\t\t"deathYear": 1958\n\t\t}, {\n\t\t\t"birthYear": 1912,\n\t\t\t"deathYear": 1946\n\t\t}, {\n\t\t\t"birthYear": 1936,\n\t\t\t"deathYear": 1983\n\t\t}, {\n\t\t\t"birthYear": 1908,\n\t\t\t"deathYear": 1930\n\t\t}, {\n\t\t\t"birthYear": 1908,\n\t\t\t"deathYear": 1949\n\t\t}, {\n\t\t\t"birthYear": 1935,\n\t\t\t"deathYear": 1981\n\t\t}, {\n\t\t\t"birthYear": 1948,\n\t\t\t"deathYear": 1989\n\t\t}, {\n\t\t
# ...

# %%
f.close()

# %%
js = json.loads(c)
js
# Out:
# {'data': [{'birthYear': 1923, 'deathYear': 1926},
#   {'birthYear': 1920, 'deathYear': 1961},
#   {'birthYear': 1941, 'deathYear': 1971},
#   {'birthYear': 1902, 'deathYear': 1936},
#   {'birthYear': 1948, 'deathYear': 1949},
#   {'birthYear': 1924, 'deathYear': 1946},
#   {'birthYear': 1914, 'deathYear': 1958},
#   {'birthYear': 1930, 'deathYear': 1965},
#   {'birthYear': 1939, 'deathYear': 1971},
#   {'birthYear': 1940, 'deathYear': 1958},
#   {'birthYear': 1912, 'deathYear': 1946},
#   {'birthYear': 1936, 'deathYear': 1983},
#   {'birthYear': 1908, 'deathYear': 1930},
#   {'birthYear': 1908, 'deathYear': 1949},
#   {'birthYear': 1935, 'deathYear': 1981},
#   {'birthYear': 1948, 'deathYear': 1989},
#   {'birthYear': 1916, 'deathYear': 1960},
#   {'birthYear': 1948, 'deathYear': 1978},
#   {'birthYear': 1902, 'deathYear': 1905},
#   {'birthYear': 1928, 'deathYear': 1967},
#   {'birthYear': 1910, 'deathYear': 1955},
#   {'birthYear': 1940, 'deathYear': 1948},
# ...

# %%
import json
f = open("data.json","r")
c=f.read()
c

lista=json.loads(c)

print(lista)
for elemento in lista:
  print("{elemento['birthYear']} {elemento['deathYear'}")
# Out:
# {'data': [{'birthYear': 1923, 'deathYear': 1926}, {'birthYear': 1920, 'deathYear': 1961}, {'birthYear': 1941, 'deathYear': 1971}, {'birthYear': 1902, 'deathYear': 1936}, {'birthYear': 1948, 'deathYear': 1949}, {'birthYear': 1924, 'deathYear': 1946}, {'birthYear': 1914, 'deathYear': 1958}, {'birthYear': 1930, 'deathYear': 1965}, {'birthYear': 1939, 'deathYear': 1971}, {'birthYear': 1940, 'deathYear': 1958}, {'birthYear': 1912, 'deathYear': 1946}, {'birthYear': 1936, 'deathYear': 1983}, {'birthYear': 1908, 'deathYear': 1930}, {'birthYear': 1908, 'deathYear': 1949}, {'birthYear': 1935, 'deathYear': 1981}, {'birthYear': 1948, 'deathYear': 1989}, {'birthYear': 1916, 'deathYear': 1960}, {'birthYear': 1948, 'deathYear': 1978}, {'birthYear': 1902, 'deathYear': 1905}, {'birthYear': 1928, 'deathYear': 1967}, {'birthYear': 1910, 'deathYear': 1955}, {'birthYear': 1940, 'deathYear': 1948}, {'birthYear': 1901, 'deathYear': 1937}, {'birthYear': 1932, 'deathYear': 1969}, {'birthYear': 1922, 'deathYe
# ...

# %%
import pandas as pd
f = open("data.json","r")


df = pd.read_json(f, orient ='index')
print(df)
# Out:
#                                         0     ...                                    4999
# data  {'birthYear': 1923, 'deathYear': 1926}  ...  {'birthYear': 1923, 'deathYear': 1935}
#
# [1 rows x 5000 columns]

# %%
import json
import pandas as pd


with open('data.json') as json_file:
    datos = json.load(json_file)


with open('data.json') as json_file:
    datos1 = pd.read_json(json_file, orient='index')

print(datos)
print(datos1)
# Out:
# {'data': [{'birthYear': 1923, 'deathYear': 1926}, {'birthYear': 1920, 'deathYear': 1961}, {'birthYear': 1941, 'deathYear': 1971}, {'birthYear': 1902, 'deathYear': 1936}, {'birthYear': 1948, 'deathYear': 1949}, {'birthYear': 1924, 'deathYear': 1946}, {'birthYear': 1914, 'deathYear': 1958}, {'birthYear': 1930, 'deathYear': 1965}, {'birthYear': 1939, 'deathYear': 1971}, {'birthYear': 1940, 'deathYear': 1958}, {'birthYear': 1912, 'deathYear': 1946}, {'birthYear': 1936, 'deathYear': 1983}, {'birthYear': 1908, 'deathYear': 1930}, {'birthYear': 1908, 'deathYear': 1949}, {'birthYear': 1935, 'deathYear': 1981}, {'birthYear': 1948, 'deathYear': 1989}, {'birthYear': 1916, 'deathYear': 1960}, {'birthYear': 1948, 'deathYear': 1978}, {'birthYear': 1902, 'deathYear': 1905}, {'birthYear': 1928, 'deathYear': 1967}, {'birthYear': 1910, 'deathYear': 1955}, {'birthYear': 1940, 'deathYear': 1948}, {'birthYear': 1901, 'deathYear': 1937}, {'birthYear': 1932, 'deathYear': 1969}, {'birthYear': 1922, 'deathYe
# ...

# %%
import json
f = open("data.json","r")
c=f.read()
c

lista=json.loads(c)

print(lista)
# Out:
# {'data': [{'birthYear': 1923, 'deathYear': 1926}, {'birthYear': 1920, 'deathYear': 1961}, {'birthYear': 1941, 'deathYear': 1971}, {'birthYear': 1902, 'deathYear': 1936}, {'birthYear': 1948, 'deathYear': 1949}, {'birthYear': 1924, 'deathYear': 1946}, {'birthYear': 1914, 'deathYear': 1958}, {'birthYear': 1930, 'deathYear': 1965}, {'birthYear': 1939, 'deathYear': 1971}, {'birthYear': 1940, 'deathYear': 1958}, {'birthYear': 1912, 'deathYear': 1946}, {'birthYear': 1936, 'deathYear': 1983}, {'birthYear': 1908, 'deathYear': 1930}, {'birthYear': 1908, 'deathYear': 1949}, {'birthYear': 1935, 'deathYear': 1981}, {'birthYear': 1948, 'deathYear': 1989}, {'birthYear': 1916, 'deathYear': 1960}, {'birthYear': 1948, 'deathYear': 1978}, {'birthYear': 1902, 'deathYear': 1905}, {'birthYear': 1928, 'deathYear': 1967}, {'birthYear': 1910, 'deathYear': 1955}, {'birthYear': 1940, 'deathYear': 1948}, {'birthYear': 1901, 'deathYear': 1937}, {'birthYear': 1932, 'deathYear': 1969}, {'birthYear': 1922, 'deathYe
# ...
